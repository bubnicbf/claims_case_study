# %%
import pandas as pd
import os

# Reading data frome excel
excel_file_path = os.path.join(os.path.dirname(os.getcwd()), 'doc', 'case_study_data.xlsx')

# Reading each sheet into a separate DataFrame
df_facilities = pd.read_excel(excel_file_path, sheet_name='Facilities')
df_prov_fac_claims = pd.read_excel(excel_file_path, sheet_name='Provider-Facility Affiliated Cl')
df_prov_demog = pd.read_excel(excel_file_path, sheet_name='Provider Demographics')

# Displaying the first few rows of each DataFrame
print("Facilities:\n", df_facilities.head())
print("\nProvider-Facility Affiliated CL:\n", df_prov_fac_claims.head())
print("\nProvider Demographics:\n", df_prov_demog.head())
# Out:
# Facilities:
#          Unnamed: 0        Unnamed: 1          Unnamed: 2  \
# 0    enrollment_id  enrollment_state  provider_type_code
# 1  O20051101000429                OH               00-09
# 2  O20051115000044                OH               00-09
# 3  O20070216000074                OH               00-09
# 4  O20070806000006                OH               00-09
#
#                    Unnamed: 3  Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# 0          provider_type_text         npi  mulitple_npi        ccn
# 1  PART A PROVIDER - HOSPITAL  1194763045             N     360087
# 2  PART A PROVIDER - HOSPITAL  1215989611             N     360077
# 3  PART A PROVIDER - HOSPITAL  1043397292             Y     369807
# 4  PART A PROVIDER - HOSPITAL  1700828852             Y     360059
#
#      Unnamed: 7                                     Unnamed: 8  \
# 0  associate_id                              organization_name
# 1    2466358387                              LUTHERAN HOSPITAL
# 2    4688571730                              FAIRVIEW HOSPITAL
# 3    3274431879  UNIVERSITY HOSPITALS CLEVELAND MEDICAL CENTER
# 4    8628982949                         THE METROHEALTH SYSTEM
#
#                     Unnamed: 9  ...              Unnamed: 29  \
# 0       doing_business_as_name  ...  subgroup_shortterm_flag
# 1                          NaN  ...                        N
# 2                          NaN  ...                        N
# 3  UH CLEVELAND MEDICAL CENTER  ...                        Y
# 4                          NaN  ...                        N
#
#                        Unnamed: 30                     Unnamed: 31  \
# 0  subgroup_swingbed_approved_flag  subgroup_psychiatric_unit_flag
# 1                                N                               N
# 2                                N                               N
# 3                                N                               Y
# 4                                N                               Y
#
#                          Unnamed: 32                        Unnamed: 33  \
# 0  subgroup_rehabilitation_unit_flag  subgroup_speciality_hospital_flag
# 1                                  N                                  N
# 2                                  N                                  N
# 3                                  N                                  N
# 4                                  Y                                  N
#
#            Unnamed: 34          Unnamed: 35                   Unnamed: 36  \
# 0  subgroup_other_flag  subgroup_other_text  subgroup_reh_conversion_flag
# 1                    N                  NaN                             N
# 2                    N                  NaN                             N
# 3                    N                  NaN                             N
# 4                    N                  NaN                             N
#
#                     Unnamed: 37       Unnamed: 38
# 0  subgroup_reh_conversion_date  subgroup_cah_ccn
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
#
# [5 rows x 39 columns]
#
# Provider-Facility Affiliated CL:
#     Clinician NPI  Facility NPI                   Healthcare Organization Name  \
# 0     1225617533    1679525919                THE CLEVELAND CLINIC FOUNDATION
# 1     1942213277    1194763045                              LUTHERAN HOSPITAL
# 2     1437110632    1043397292  UNIVERSITY HOSPITALS CLEVELAND MEDICAL CENTER
# 3     1427587070    1679525919                THE CLEVELAND CLINIC FOUNDATION
# 4     1306369731    1679525919                THE CLEVELAND CLINIC FOUNDATION
#
#                          class  year  quarter  total_claims  total_patients
# 0  GENERAL ACUTE CARE HOSPITAL  2022        1             0               0
# 1  GENERAL ACUTE CARE HOSPITAL  2022        1             6               6
# 2  GENERAL ACUTE CARE HOSPITAL  2022        1             0               0
# 3  GENERAL ACUTE CARE HOSPITAL  2022        1             0               0
# 4  GENERAL ACUTE CARE HOSPITAL  2022        1             0               0
#
# Provider Demographics:
#            NPI      Provider Name                                 Type  \
# 0  1003000423   JENNIFER VELOTTA  ALLOPATHIC & OSTEOPATHIC PHYSICIANS
# 1  1003010174   ALEXANDER USOROV  ALLOPATHIC & OSTEOPATHIC PHYSICIANS
# 2  1003021973    ALEXANDRA ZHANG  ALLOPATHIC & OSTEOPATHIC PHYSICIANS
# 3  1003022807  CATHERINE DABRAMO  ALLOPATHIC & OSTEOPATHIC PHYSICIANS
# 4  1003049115      CASSIE CARNEY  ALLOPATHIC & OSTEOPATHIC PHYSICIANS
#
#                  Specialty                           Subspecialty  \
# 0  OBSTETRICS & GYNECOLOGY                                    NaN
# 1        INTERNAL MEDICINE                             NEPHROLOGY
# 2              DERMATOLOGY                                    NaN
# 3       EMERGENCY MEDICINE                                    NaN
# 4           OTOLARYNGOLOGY  OTOLARYNGOLOGY/FACIAL PLASTIC SURGERY
#
#           Phone              Address Address Line 2       City State    Zip  \
# 0  2.168441e+09     11100 EUCLID AVE            NaN  CLEVELAND    OH  44106
# 1  7.188586e+09     447 ATLANTIC AVE            NaN   BROOKLYN    NY  11217
# 2  3.305357e+09    566 WHITE POND DR        SUITE E      AKRON    OH  44320
# 3  2.167788e+09  2500 METROHEALTH DR            NaN  CLEVELAND    OH  44109
# 4  5.632433e+09       915 13TH AVE N            NaN    CLINTON    IA  52732
#
#   Provider Credentials
# 0                 M.D.
# 1                   MD
# 2                   MD
# 3                   MD
# 4                 D.O.
